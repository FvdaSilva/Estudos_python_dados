# %% [markdown]
# <a href="https://colab.research.google.com/github/FvdaSilva/Estudos_python_dados/blob/main/GRUPO_2_Projeto_Python_aplicado_%C3%A0_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto - Python aplicado à Dados
#
#
# ![banner-notebook.png](data:image/png;base64,...)

# %% [markdown]
# Neste projeto você vai analisar um conjunto novo de dados, que ainda não foi visto na disciplina.
# O ideal é que escolha um conjunto de dados do seu interesse, para que além de mostrar os conhecimentos adquiridos durante a disciplina também tire proveito do projeto para trazer mais conhecimento sobre o conjunto de dados analisado.
#
# O conjunto de dados deve ter as seguintes características:
# * Pelo menos duas colunas numéricas
# * Pelo menos uma coluna categórica
#
# Caso ainda não tenha escolhido o conjunto de dados, seguem algumas opções:
#
# * [Fraudes de cartões de crédito](https://www.kaggle.com/datasets/kelvinkelue/credit-card-fraud-prediction)
# * [Premier Legue](https://www.kaggle.com/datasets/ajaxianazarenka/premier-league)
# * [Pedidos de comida online](https://www.kaggle.com/datasets/sudarshan24byte/online-food-dataset)
# * [Músicas mais tocadas no Spotify](https://www.kaggle.com/datasets/arnavvvvv/spotify-music)

# %% [markdown]
# ## Equipe 2, 19/06/2025
#
# * Fernanda Viana
# * Kerly Amorim
# * Hugo Silveira

# %% [markdown]
# ## 1. Importe o Numpy, Pandas e Seaborn, e carregue o conjunto de dados

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import kagglehub

path = kagglehub.dataset_download("arnavvvvv/spotify-music")

# %%
import os
print (path)
# Out:
# /kaggle/input/spotify-music

# %%
spotify=pd.read_csv("/kaggle/input/spotify-music/Popular_Spotify_Songs.csv",encoding='latin-1')

# %% [markdown]
# ## 2. Entenda e inspecione seu conjunto de dados
#
# * Veja as primeiras 5 linhas do DataFrame
# * Veja as informações do DataFrame
# * Veja a descrição estatística das variáveis numéricas

# %%
spotify.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
spotify.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# ## 3. Estruture seu conjunto de dados
#
# * Veja se é necessário remover colunas
# * Veja se é necessário renomear colunas
# * Veja se é necessário realizar um cast de alguma coluna (trocar o tipo dos dados para float, datetime, etc.)
# * Busque por dados faltantes
#     * Entenda se eles podem ser substituídos por outros valores, como a média do valor, ou um valor coringa como "desconhecido"
#     * Entenda se eles podem ser removidos sem prejuízo substancial

# %%
spotify = spotify.dropna(subset="in_shazam_charts")

# %%
spotify = spotify.dropna(subset="key")

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            817 non-null    object
#  1   artist(s)_name        817 non-null    object
#  2   artist_count          817 non-null    int64
#  3   released_year         817 non-null    int64
#  4   released_month        817 non-null    int64
#  5   released_day          817 non-null    int64
#  6   in_spotify_playlists  817 non-null    int64
#  7   in_spotify_charts     817 non-null    int64
#  8   streams               817 non-null    object
#  9   in_apple_playlists    817 non-null    int64
#  10  in_apple_charts       817 non-null    int64
#  11  in_deezer_playlists   817 non-null    object
#  12  in_deezer_charts      817 non-null    int64
#  13  in_shazam_charts      817 non-null    object
#  14  bpm                   817 non-null    int64
# ...

# %%
spotify_tratado = spotify.rename(columns={
    "track_name": "nome_da_musica",
    "artist(s)_name": "nome_do_artista",
    "artist_count": "qtd_artistas",
    "released_year": "ano_lancamento",
    "released_month": "mes_lancamento",
    "released_day": "dia_lancamento",
    "in_spotify_playlists": "em_playlists_spotify",
    "in_spotify_charts": "nos_charts_spotify",
    "in_apple_playlists": "em_playlists_apple",
    "in_apple_charts": "nos_charts_apple",
    "in_deezer_playlists": "em_playlists_deezer",
    "in_deezer_charts": "nos_charts_deezer",
    "bpm": "batimentos_por_minuto",
    "nrgy": "energia",
    "dnce": "dancabilidade",
    "valence_%": "positividade",
    "acousticness_%": "acusticidade",
    "instrumentalness_%": "instrumentalidade",
    "liveness_%": "vivacidade",
    "speechiness_%": "fala"
}, inplace=False)

spotify_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nome_da_musica         817 non-null    object
#  1   nome_do_artista        817 non-null    object
#  2   qtd_artistas           817 non-null    int64
#  3   ano_lancamento         817 non-null    int64
#  4   mes_lancamento         817 non-null    int64
#  5   dia_lancamento         817 non-null    int64
#  6   em_playlists_spotify   817 non-null    int64
#  7   nos_charts_spotify     817 non-null    int64
#  8   streams                817 non-null    object
#  9   em_playlists_apple     817 non-null    int64
#  10  nos_charts_apple       817 non-null    int64
#  11  em_playlists_deezer    817 non-null    object
#  12  nos_charts_deezer      817 non-null    int64
#  13  in_shazam_charts       817 non-null    object
#  14  batimentos_por_minuto  817 non-null    int64
# ...

# %%
spotify_tratado.head()
# Out:
#                         nome_da_musica   nome_do_artista  qtd_artistas  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    ano_lancamento  mes_lancamento  dia_lancamento  em_playlists_spotify  \
# 0            2023               7              14                   553
# 1            2023               3              23                  1474
# 2            2023               6              30                  1397
# 3            2019               8              23                  7858
# 4            2023               5              18                  3133
#
#    nos_charts_spotify    streams  em_playlists_apple  ...  \
# ...

# %%
#true_remove = ["BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3"]
spotify_tratado = spotify_tratado.query(
 "streams != 'BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3'"
).assign(streams=spotify_tratado.streams.astype(int))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-83-2228654878.py in <cell line: 0>()
#       2 spotify_tratado = spotify_tratado.query(
#       3  "streams != 'BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3'"
# ----> 4 ).assign(streams=spotify_tratado.streams.astype(int))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# ...

# %%
#true_remove = ["BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3"]
spotify_tratado = spotify_tratado.query(
 "~ streams.str.contains('B')"
)#
spotify_tratado=spotify_tratado.assign(streams=spotify_tratado.streams.astype(int))

spotify_tratado.head()
# Out:
#                         nome_da_musica   nome_do_artista  qtd_artistas  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    ano_lancamento  mes_lancamento  dia_lancamento  em_playlists_spotify  \
# 0            2023               7              14                   553
# 1            2023               3              23                  1474
# 2            2023               6              30                  1397
# 3            2019               8              23                  7858
# 4            2023               5              18                  3133
#
#    nos_charts_spotify    streams  em_playlists_apple  ...  \
# ...

# %%
spotify_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nome_da_musica         816 non-null    object
#  1   nome_do_artista        816 non-null    object
#  2   qtd_artistas           816 non-null    int64
#  3   ano_lancamento         816 non-null    int64
#  4   mes_lancamento         816 non-null    int64
#  5   dia_lancamento         816 non-null    int64
#  6   em_playlists_spotify   816 non-null    int64
#  7   nos_charts_spotify     816 non-null    int64
#  8   streams                816 non-null    int64
#  9   em_playlists_apple     816 non-null    int64
#  10  nos_charts_apple       816 non-null    int64
#  11  em_playlists_deezer    816 non-null    object
#  12  nos_charts_deezer      816 non-null    int64
#  13  in_shazam_charts       816 non-null    object
#  14  batimentos_por_minuto  816 non-null    int64
# ...

# %% [markdown]
# ## 4. Veja a distribuição das variáveis numéricas presentes no conjunto de dados
#
# * Utilize uma visualização de dados para ver a distribuição das variáveis numéricas
# * Identifique se existem outliers nos dados
#     * Busque por valores discrepantes nos dados
#     * Entenda se eles podem ser removidos, sendo valores que não fazem sentido, ou se são valores razoáveis que podem ser deixados

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


colunas_numericas = spotify_tratado.select_dtypes(include=['int64', 'float64']).columns


plt.figure(figsize=(20, 20))
for i, coluna in enumerate(colunas_numericas, 1):
    plt.subplot(6, 3, i)
    sns.histplot(data=spotify_tratado, x=coluna, kde=True, color='skyblue')
    plt.title(f'Distribuição de {coluna}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 20))
for i, coluna in enumerate(colunas_numericas, 1):
    plt.subplot(6, 3, i)
    sns.boxplot(data=spotify_tratado[coluna], color='orange')
    plt.title(f'Boxplot de {coluna}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Enumere 3 perguntas que podem ser respondidas com visualização:
#
# * Uma das perguntas deve tratar relação entre duas variáveis numéricas
# * Uma das perguntas deve comparar pelo menos uma variável numérica em diferentes categorias
#   * Esta pergunta deve utilizar `groupby + agreggate` para agrupar pela categoria e agregar os valores das categorias com uma função que resume os dados
# * A última pergunta é livre, para ter o entendimento dos dados

# %% [markdown]
# ### Pergunta 1: *QUAL ARTISTA COM MAIOR QUANTIDADE DE MÚSICA TOCADAS?*

# %%
spotify_tratado.groupby('nome_do_artista')['streams'].sum().nlargest(5).reset_index()
# Out:
#   nome_do_artista      streams
# 0    Taylor Swift  11851151082
# 1      Ed Sheeran  11051252012
# 2       Bad Bunny   8582384095
# 3          Eminem   6183805596
# 4      The Weeknd   6038640754

# %%
top5_artistas = spotify_tratado.groupby('nome_do_artista')['streams'].sum().nlargest(5)

top5_artistas.plot(kind='barh', title='Top 5 Artistas com Mais Streams')
plt.xlabel('Total de Streams')
plt.ylabel('Artista')
plt.tight_layout()
plt.show()

# %% [markdown]
# Responda aqui, de forma textual, a pergunta que trata comparação de pelo menos uma variável numérica em diferentes categorias:
#
# Pelo gráfico, dá pra ver que a Taylor Swift foi a artista mais ouvida, com mais de 11 bilhões de streams. Depois vem o Ed Sheeran, que também tem muita música tocada, seguido pelo Bad Bunny, Eminem e The Weeknd.
# Comparando a quantidade de streams (que é um número) entre esses artistas (que são categorias diferentes), dá pra perceber que alguns se destacam muito mais do que outros. Isso mostra que alguns artistas têm um alcance bem maior nas plataformas, talvez por terem mais hits ou mais fãs mesmo.

# %% [markdown]
# ### Pergunta 2:   QUAL MÊS QUE TEV A MAIOR QUANTIDADE DE MÚSICA TOCADA CORRELACIONANDO COM O ARTISTA?

# %%
spotify_tratado.groupby(['mes_lancamento', 'nome_do_artista'])['streams'] \
    .sum().reset_index().sort_values(by='streams', ascending=False).head(5)
# Out:
#      mes_lancamento  nome_do_artista     streams
# 20                1       Ed Sheeran  8402639056
# 272               5        Bad Bunny  7009166660
# 23                1           Eminem  6183805596
# 73                1     Taylor Swift  4760471957
# 31                1  Imagine Dragons  4434404750

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dados = {
    'Ed Sheeran': {1: 8402639056},
    'Bad Bunny': {5: 7009166660},
    'Eminem': {1: 6183805596},
    'Taylor Swift': {1: 4760471957},
    'Imagine Dragons': {1: 4434404750}
}

import pandas as pd
tabela = pd.DataFrame(dados).T

sns.heatmap(tabela, annot=True, fmt=".0f", cmap="Blues")
plt.title("Streams por Artista e Mês de Lançamento")
plt.xlabel("Mês")
plt.ylabel("Artista")
plt.show()

# %% [markdown]
# Responda aqui, de forma textual, a pergunta que trata relação entre duas variáveis numéricas:
#
# Analisando a tabela, dá pra ver uma relação entre o mês de lançamento e a quantidade de streams que os artistas tiveram. Por exemplo, o Ed Sheeran teve mais de 8 bilhões de streams em músicas lançadas no mês 1 (janeiro), e outros artistas como Eminem, Taylor Swift e Imagine Dragons também tiveram muitos streams nesse mesmo mês.
# Isso nos fez perceber que janeiro pode ser um mês bom pra lançar músicas, já que vários artistas com bastante sucesso têm lançamentos nesse período. Então, dá pra perceber uma relação entre duas variáveis numéricas: o mês de lançamento e a quantidade de streams que as músicas tiveram.

# %% [markdown]
# ### Pergunta 3: *QUAL MÚSICA MAIS VIBRANTE?*

# %%
spotify_tratado.groupby('nome_da_musica')['batimentos_por_minuto'] \
    .mean().reset_index().sort_values(by='batimentos_por_minuto', ascending=False).head(5)
# Out:
#                                nome_da_musica  batimentos_por_minuto
# 390                                     Lover                  206.0
# 360                                Last Night                  204.0
# 321  It's the Most Wonderful Time of the Year                  202.0
# 730                         Until I Found You                  202.0
# 475                                       O.O                  200.0

# %%
from matplotlib import pyplot as plt
_df_36['batimentos_por_minuto'].plot(kind='hist', bins=20, title='batimentos_por_minuto')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Responda aqui, de forma textual, a terceira pergunta:
#
# Pela tabela, a música mais vibrante é "Lover", porque ela tem o maior número de batimentos por minuto (BPM), que é 206.0. Como o BPM indica o ritmo da música, quanto maior esse número, mais acelerada e animada ela costuma ser. Por isso, entre as músicas da lista, "Lover" é a que tem o ritmo mais acelerado e provavelmente passa uma sensação de mais energia.
